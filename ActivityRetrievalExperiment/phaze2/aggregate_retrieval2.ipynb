# %%
Expected = {'knitting_colorful_scarves':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  , 
            'spinning_pottery':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  , 
            'baking_a_cake':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  , 
            'skating_in_a_roller_derby':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  , 
            'doing_basket_weaving':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  ,
            'doing_professional_makeup':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  ,
            'having_face_mask':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  ,
            'designing_dress':['woman_man_binding' , 'woman_man_2_binding' , 'woman_binding' ]  ,

            'repairing_electronics':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            'designing_a_building':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            'diving_from_a_high_board':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            'playing_acoustic_guitar':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            'customizing_a_motorcycle':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            'programming_new_software':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            'tuning_a_guitar':['man_woman_binding' , 'man_woman_2_binding' , 'man_binding' ] ,
            }

# %%
listCatrgory = ['man_woman_2_binding' , 'woman_man_2_binding' , 'man_woman_binding' , 'woman_man_binding' , 'man_binding' , 'woman_binding']

# %%
actionList = ['knitting_colorful_scarves' , 'spinning_pottery'
              , 'baking_a_cake' , 'skating_in_a_roller_derby' 
              , 'doing_basket_weaving' , 'doing_professional_makeup' ,'having_face_mask'  ,'designing_dress' ,'repairing_electronics' , 'designing_a_building'
              , 'diving_from_a_high_board' , 'playing_acoustic_guitar' 
              , 'customizing_a_motorcycle'  ,  'programming_new_software' , 'tuning_a_guitar']

# %%
def calculate_metrics(prob_lists):
    recall_at_1 = 0
    recall_at_3 = 0
    mrr = 0.0

    for probs in prob_lists:
        sorted_indices = sorted(range(len(probs)), key=lambda i: probs[i], reverse=True)
        
        correct_rank = sorted_indices.index(0) + 1
        
        if correct_rank == 1:
            recall_at_1 += 1
        if correct_rank <= 3:
            recall_at_3 += 1
        
        mrr += 1 / correct_rank
        
    num_lists = len(prob_lists)
    recall_at_1 /= num_lists
    recall_at_3 /= num_lists
    mrr /= num_lists

    return recall_at_1, recall_at_3, mrr

# %%
sourcePath = '../../phaze2/Phaze-2'

# %%
import pandas as pd 
import ast

column_names = ['model', 'Recall@1' , 'Recall@3' , 'MRR' , 'action' ]
dfExpectedTwo = pd.DataFrame(columns=column_names)
dfExpectedTwo2 = pd.DataFrame(columns=column_names)
dfUnExpectedTwo = pd.DataFrame(columns=column_names)
dfUnExpectedTwo2 = pd.DataFrame(columns=column_names)
dfUnExpectedSingle = pd.DataFrame(columns=column_names)
dfExpectedSingle = pd.DataFrame(columns=column_names)
dfSingle = pd.DataFrame(columns=column_names)
dfTwo = pd.DataFrame(columns=column_names)
dfTwo2 = pd.DataFrame(columns=column_names)

for action in actionList:
    for category in listCatrgory:
        df = pd.read_csv(f'{sourcePath}/{action}/{category}.csv')
        for model, group in df.groupby('model'):
            correct_predictions = 0
            total_predictions = len(group) // 2  

            listProbs = []
            for val in group['probs']:
                listProbs.append(ast.literal_eval(val))

            recall_at_1, recall_at_3, mrr = calculate_metrics(listProbs)
            if category == 'woman_man_2_binding' or category == 'man_woman_2_binding':
                if category in Expected[action]:
                    dfExpectedTwo2.loc[len(dfExpectedTwo2.index)] = [model , recall_at_1, recall_at_3, mrr ,action ]
                else:
                    dfUnExpectedTwo2.loc[len(dfUnExpectedTwo2.index)] = [model , recall_at_1, recall_at_3, mrr ,action ]
                dfTwo2.loc[len(dfTwo2.index)] = [model , recall_at_1, recall_at_3, mrr ,action ]
            if category == 'woman_man_binding' or category == 'man_woman_binding':
                if category in Expected[action]:
                    dfExpectedTwo.loc[len(dfExpectedTwo.index)] = [model , recall_at_1, recall_at_3, mrr ,action]
                else:
                    dfUnExpectedTwo.loc[len(dfUnExpectedTwo.index)] = [model , recall_at_1, recall_at_3, mrr,action  ]
                dfTwo.loc[len(dfTwo.index)] = [model , recall_at_1, recall_at_3, mrr ,action ]
            if category == 'man_binding' or category == 'woman_binding':
                if category in Expected[action]:
                    dfExpectedSingle.loc[len(dfExpectedSingle.index)] = [model , recall_at_1, recall_at_3, mrr,action  ]
                else:
                    dfUnExpectedSingle.loc[len(dfUnExpectedSingle.index)] = [model , recall_at_1, recall_at_3, mrr,action  ]
                dfSingle.loc[len(dfSingle.index)] = [model , recall_at_1, recall_at_3, mrr ,action ]

# %%
dictModels =  {
    'align_kakaobrain/align-base': 'Align',
    'alt_BAAI/AltCLIP' : 'AltCLIP',
    'flava_facebook/flava-full' : 'Flava',
    'openai_EVA01-g-14 laion400m_s11b_b41k': 'EVA01-g-14',
    'openai_EVA02-L-14 merged2b_s4b_b131k': 'EVA02-L-14',
    'openai_RN50x64 openai': 'CLIP-RN50x64',
    'openai_ViT-B-16 openai':'CLIP-ViT-B-16',
    # 'openai_ViT-B-32 negCLIP.pt':'NegCLIP-ViT-B-32', # first download and add negClip weights in this directory
    'openai_ViT-B-32 openai' : 'CLIP-ViT-B-32',
    'openai_ViT-L-14 openai':'CLIP-ViT-L-14',
    'openai_coca_ViT-B-32 laion2b_s13b_b90k':'coca_ViT-B-32' , 
    'openai_coca_ViT-L-14 laion2b_s13b_b90k':'coca_ViT-L-14',
}

# %%
dfSingle_deleted = dfSingle[dfSingle['model'].isin(dictModels.keys())]
avg_acc = dfSingle_deleted.groupby(['model'])['MRR' , 'Recall@1' , 'Recall@3'].mean().reset_index()
avg_acc
# Out:
# C:\Users\EA\AppData\Local\Temp\ipykernel_19500\2558110551.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_acc = dfSingle_deleted.groupby(['model'])['MRR' , 'Recall@1' , 'Recall@3'].mean().reset_index()
#                                      model       MRR  Recall@1  Recall@3
# 0              align_kakaobrain/align-base  0.534885  0.375479  0.620437
# 1                         alt_BAAI/AltCLIP  0.677527  0.553646  0.732214
# 2                flava_facebook/flava-full  0.474548  0.283885  0.554339
# 3    openai_EVA01-g-14 laion400m_s11b_b41k  0.585640  0.425222  0.671888
# 4     openai_EVA02-L-14 merged2b_s4b_b131k  0.687642  0.563759  0.761190
# 5                    openai_RN50x64 openai  0.601720  0.465451  0.648599
# 6                   openai_ViT-B-16 openai  0.483705  0.333760  0.531243
# 7                   openai_ViT-B-32 openai  0.296222  0.128469  0.316118
# 8                   openai_ViT-L-14 openai  0.606996  0.470025  0.673281
# 9   openai_coca_ViT-B-32 laion2b_s13b_b90k  0.319150  0.137221  0.382654
# 10  openai_coca_ViT-L-14 laion2b_s13b_b90k  0.459428  0.280211  0.529358

# %%
dfTwo_deleted = dfTwo[dfTwo['model'].isin(dictModels.keys())]
avg_acc = dfTwo_deleted.groupby(['model'])['MRR' , 'Recall@1' , 'Recall@3'].mean().reset_index()
avg_acc
# Out:
# C:\Users\EA\AppData\Local\Temp\ipykernel_19500\2507834131.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_acc = dfTwo_deleted.groupby(['model'])['MRR' , 'Recall@1' , 'Recall@3'].mean().reset_index()
#                                      model       MRR  Recall@1  Recall@3
# 0              align_kakaobrain/align-base  0.541675  0.391042  0.625715
# 1                         alt_BAAI/AltCLIP  0.641742  0.496423  0.726714
# 2                flava_facebook/flava-full  0.406239  0.235568  0.466491
# 3    openai_EVA01-g-14 laion400m_s11b_b41k  0.585228  0.433587  0.651670
# 4     openai_EVA02-L-14 merged2b_s4b_b131k  0.694659  0.585329  0.736904
# 5                    openai_RN50x64 openai  0.496611  0.339862  0.572014
# 6                   openai_ViT-B-16 openai  0.576368  0.434381  0.654672
# 7                   openai_ViT-B-32 openai  0.409536  0.246473  0.442464
# 8                   openai_ViT-L-14 openai  0.661306  0.518215  0.742935
# 9   openai_coca_ViT-B-32 laion2b_s13b_b90k  0.403304  0.247961  0.447393
# 10  openai_coca_ViT-L-14 laion2b_s13b_b90k  0.558237  0.390470  0.665101

# %%
dfTwo2_deleted = dfTwo2[dfTwo2['model'].isin(dictModels.keys())]
avg_acc = dfTwo2_deleted.groupby(['model'])['MRR' , 'Recall@1' , 'Recall@3'].mean().reset_index()
avg_acc
# Out:
# C:\Users\EA\AppData\Local\Temp\ipykernel_19500\1961913323.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg_acc = dfTwo2_deleted.groupby(['model'])['MRR' , 'Recall@1' , 'Recall@3'].mean().reset_index()
#                                      model       MRR  Recall@1  Recall@3
# 0              align_kakaobrain/align-base  0.498662  0.332885  0.590669
# 1                         alt_BAAI/AltCLIP  0.592848  0.449105  0.659092
# 2                flava_facebook/flava-full  0.469460  0.281495  0.539402
# 3    openai_EVA01-g-14 laion400m_s11b_b41k  0.513693  0.365915  0.564426
# 4     openai_EVA02-L-14 merged2b_s4b_b131k  0.563713  0.416532  0.634849
# 5                    openai_RN50x64 openai  0.494854  0.333665  0.557784
# 6                   openai_ViT-B-16 openai  0.456512  0.310778  0.487032
# 7                   openai_ViT-B-32 openai  0.269814  0.111247  0.276057
# 8                   openai_ViT-L-14 openai  0.550272  0.403152  0.618234
# 9   openai_coca_ViT-B-32 laion2b_s13b_b90k  0.292492  0.128171  0.314728
# 10  openai_coca_ViT-L-14 laion2b_s13b_b90k  0.419490  0.245897  0.488946
